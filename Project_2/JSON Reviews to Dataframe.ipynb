# %%
import json
import pandas as pd

# %%
file_path = '/content/Competitors_data_9.json'
with open(file_path, 'r') as file:
    data = json.load(file)

# %%
reviews_data = []
count = 0
for result in data['results']:
  asin = result['content']["asin"]
  for review in result['content']['reviews']:
    count += 1
    try:
      review_info = {
      'review_id': review['id'],
      'product_id': asin,
      "title": review["title"],
      "author": review["author"],
      "rating": review["rating"],
      "content": review["content"],
      "timestamp": review["timestamp"],
      "profile_id": review["profile_id"],
      "is_verified": review["is_verified"],
      "helpful_count": review.get('helpful_count', 0),
      "product_attributes": review["product_attributes"]
      }
      reviews_data.append(review_info)
    except:
      print(count)
      break

reviews_df = pd.DataFrame(reviews_data)
reviews_df.to_csv('reviews.csv', index=False)
reviews_df
# Out:
#          review_id  product_id  \
# 0   R2CM006AE5NWH5  B01HETFPUE
# 1   R2IEZBUP41NM10  B01HETFPUE
# 2   R1FTF4PGDFBTQJ  B01HETFPUE
# 3   R329QN95CVMU1M  B01HETFPUE
# 4   R2V2Q62V7E3G6W  B01HETFPUE
# ..             ...         ...
# 95  R2YDUHWXRFQOPJ  B01HETFPUE
# 96  R3QTN30QHCNEMF  B01HETFPUE
# 97  R2I19821YCEEPT  B01HETFPUE
# 98  R16ZHY844LHB1L  B01HETFPUE
# 99   RL9L23JVXVPB2  B01HETFPUE
#
#                                                 title             author  \
# 0   5.0 out of 5 stars ... got these in yesterday ...        Placeholder
# 1   5.0 out of 5 stars Nice sounding workout headp...            Buzz D.
# 2   1.0 out of 5 stars Perfect headphones, for you...      Hedley Lamarr
# 3    4.0 out of 5 stars Almost perfect but not for me       Mark Nosrati
# 4   5.0 out of 5 stars Awesome customer service by...               Abee
# ..                                                ...                ...
# 95                     1.0 out of 5 stars Never Again              bwest
# 96  5.0 out of 5 stars Wind noise reduction is sup...          Thoris B.
# 97                    1.0 out of 5 stars Never worked                 GB
# 98  1.0 out of 5 stars Don't let the brand name fo...  Electronics Junky
# 99  1.0 out of 5 stars Headphone not functioning a...     Hamad Alnamlan
#
#     rating                                            content  \
# 0        5  I just got these in yesterday so I can’t write...
# 1        5  Purchased these prior to running the 48 mile R...
# 2        1  Let me just get this out of the way now: I des...
# 3        4  Quick disclaimer. I did not buy my set from Am...
# 4        5  These have worked fabulously - these are howev...
# ..     ...                                                ...
# 95       1  Purchased this product on 7/24/2022. Did not g...
# 96       5  After trying the Powerbeats3 Wireless In-Ear H...
# 97       1  Bought it new and never would turn on or conne...
# 98       1  I have several different Bluetooth had phones ...
# 99       1  The headphone was not working from the beginning…
#
#                                           timestamp  \
# 0      Reviewed in the United States March 19, 2018
# 1      Reviewed in the United States March 26, 2019
# 2    Reviewed in the United States January 18, 2019
# 3     Reviewed in the United States January 1, 2017
# 4       Reviewed in the United States June 12, 2019
# ..                                              ...
# 95  Reviewed in the United States September 6, 2022
# 96   Reviewed in the United States January 26, 2018
# 97   Reviewed in the United States December 2, 2023
# 98    Reviewed in the United States January 2, 2017
# 99  Reviewed in the United States February 19, 2024
#
#                       profile_id  is_verified  helpful_count  \
# 0   AGNXZBIQ2EGH33KT4U3ASPSFD3JQ         True              4
# 1   AHPD5ODNTMPHSBBX6HLJJK3B6D2Q         True              0
# 2   AFYEMJQDXUNWCDPXCUVR4U23IJSA         True             19
# 3   AGGSB7KYAE4N3KY3B77FIQQ7T6DA         True              6
# 4   AHDBX4A5MZRW6HX4O5QYNEGHIP4Q         True              1
# ..                           ...          ...            ...
# 95  AEIHHPEREZXFV6DK5M5LIUJOUFWA         True              0
# 96  AE5HNV4MW7ZUI4EXI4XOFQAEQYBQ         True              0
# 97  AF2QYQTD2BBHZ2EDXKPBYVI5YH4Q         True              0
# 98  AEQBWDLF5LSUM73BOX2JVQKYZU2Q         True              2
# 99  AFA4LQTS343RHOPZW2R4AH2LPR7A         True              0
#
#    product_attributes
# 0    Color: Power Red
# 1    Color: Power Red
# 2    Color: Power Red
# 3    Color: Power Red
# 4    Color: Power Red
# ..                ...
# 95
# 96   Color: Power Red
# 97   Color: Power Red
# 98   Color: Power Red
# 99   Color: Power Red
#
# [100 rows x 11 columns]

# %%
df_1 = pd.read_csv('/content/reviews_1.csv')
df_2 = pd.read_csv('/content/reviews_2.csv')
df_3 = pd.read_csv('/content/reviews_3.csv')
df_4 = pd.read_csv('/content/reviews_4.csv')
df_5 = pd.read_csv('/content/reviews_5.csv')
df_6 = pd.read_csv('/content/reviews_6.csv')
df_7 = pd.read_csv('/content/reviews_7.csv')
df_8 = pd.read_csv('/content/reviews_8.csv')
df_9 = pd.read_csv('/content/reviews_9.csv')
df_10 = pd.read_csv('/content/reviews_10.csv')
df_11 = pd.read_csv('/content/reviews_11.csv')
df_12 = pd.read_csv('/content/reviews_12.csv')
df_13 = pd.read_csv('/content/reviews_13.csv')
df_14 = pd.read_csv('/content/reviews_14.csv')
df_15 = pd.read_csv('/content/reviews_15.csv')
df_16 = pd.read_csv('/content/reviews_16.csv')
df_17 = pd.read_csv('/content/reviews_17.csv')
df_18 = pd.read_csv('/content/reviews.csv')

df_18.head()
# Out:
#         review_id  product_id  \
# 0  R2CM006AE5NWH5  B01HETFPUE
# 1  R2IEZBUP41NM10  B01HETFPUE
# 2  R1FTF4PGDFBTQJ  B01HETFPUE
# 3  R329QN95CVMU1M  B01HETFPUE
# 4  R2V2Q62V7E3G6W  B01HETFPUE
#
#                                                title         author  rating  \
# 0  5.0 out of 5 stars ... got these in yesterday ...    Placeholder       5
# 1  5.0 out of 5 stars Nice sounding workout headp...        Buzz D.       5
# 2  1.0 out of 5 stars Perfect headphones, for you...  Hedley Lamarr       1
# 3   4.0 out of 5 stars Almost perfect but not for me   Mark Nosrati       4
# 4  5.0 out of 5 stars Awesome customer service by...           Abee       5
#
#                                              content  \
# 0  I just got these in yesterday so I can’t write...
# 1  Purchased these prior to running the 48 mile R...
# 2  Let me just get this out of the way now: I des...
# 3  Quick disclaimer. I did not buy my set from Am...
# 4  These have worked fabulously - these are howev...
#
#                                         timestamp  \
# 0    Reviewed in the United States March 19, 2018
# 1    Reviewed in the United States March 26, 2019
# 2  Reviewed in the United States January 18, 2019
# 3   Reviewed in the United States January 1, 2017
# 4     Reviewed in the United States June 12, 2019
#
#                      profile_id  is_verified  helpful_count product_attributes
# 0  AGNXZBIQ2EGH33KT4U3ASPSFD3JQ         True              4   Color: Power Red
# 1  AHPD5ODNTMPHSBBX6HLJJK3B6D2Q         True              0   Color: Power Red
# 2  AFYEMJQDXUNWCDPXCUVR4U23IJSA         True             19   Color: Power Red
# 3  AGGSB7KYAE4N3KY3B77FIQQ7T6DA         True              6   Color: Power Red
# 4  AHDBX4A5MZRW6HX4O5QYNEGHIP4Q         True              1   Color: Power Red

# %%
merged_df = pd.concat([df_1, df_2, df_3, df_4, df_5, df_6, df_7, df_8, df_9, df_10, df_11, df_12, df_13, df_14, df_15, df_16, df_17, df_18], ignore_index=True)
merged_df.to_csv('raw_data_df.csv', index=False)
