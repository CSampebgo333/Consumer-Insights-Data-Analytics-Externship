# %% [markdown]
# # **Data Cleaning**

# %% [markdown]
# ## **We will clean the dataset by:**
#
# - **1. Handling missing values**
#
# - **2. Identifying and handling outliers**
#
# - **3. Converting categorical columns to numerical variables if necessary**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Dataset loading**

# %%
raw_data_df = pd.read_csv("Reviews_Raw_Data_df.csv")

# %% [markdown]
# **Display the dataset**

# %%
raw_data_df
# Out:
#            review_id  product_id  \
# 0     R3VJHX5IUE1GW0  B09JL41N9C
# 1     R3O2F0G4RQELXK  B09JL41N9C
# 2     R35IQTO062Y7LU  B09JL41N9C
# 3     R2LFEEQXQDETXR  B09JL41N9C
# 4     R2JXCMRVKF84KR  B09JL41N9C
# ...              ...         ...
# 1031  R1D6AFLAUH1IKB  B0756CYWWD
# 1032  R139MEJ6IWDKKW  B0756CYWWD
# 1033   REEXHGPGJMEMI  B0756CYWWD
# 1034   RKAB2RDVHYYCE  B0756CYWWD
# 1035   R47X1PKQCOKLY  B0756CYWWD
#
#                                                   title            author  \
# 0     5.0 out of 5 stars Good sound, seamless iPhone...     Bobby K - NYC
# 1     5.0 out of 5 stars Movement focused TW earbuds...               Ant
# 2     5.0 out of 5 stars Best wireless noise cancell...  theInternational
# 3     4.0 out of 5 stars Good Apple Ecosystem Option...          C. Godby
# 4     5.0 out of 5 stars Elevating the Listening Exp...           Kailash
# ...                                                 ...               ...
# 1031            4.0 out of 5 stars They’re cool I guess     Yardley Rosas
# 1032                    5.0 out of 5 stars Great Seller            Joseph
# 1033  2.0 out of 5 stars Bose QuietComfort 35 Series...      VirtualWatts
# 1034    5.0 out of 5 stars Excellent noise cancelation.    Timothy Parker
# 1035  5.0 out of 5 stars What kind of idiot would pa...       Inna Tkatch
#
#       rating                                            content  \
# 0          5  I like how secure these earphones are, comfort...
# 1          5  My pair of Beats Powerbeats Pros were starting...
# 2          5  I am a long-time user of the Bose QuietComfort...
# 3          4  Before buying the Beats Fit Pro, I've owned th...
# 4          5  I recently had the pleasure of trying out the ...
# ...      ...                                                ...
# 1031       4  For the price I was low key expecting more so ...
# 1032       5  This was exactly what I was looking for and am...
# 1033       2  I was looking for a pair of headphones to help...
# 1034       5  I bought these specifically for the noise canc...
# 1035       5  Back when I used to spend my days fumbling wit...
#
#                                            timestamp  \
# 0         Reviewed in the United States June 6, 2024
# 1        Reviewed in the United States March 8, 2024
# 2        Reviewed in the United States July 13, 2022
# 3     Reviewed in the United States February 8, 2023
# 4       Reviewed in the United States March 21, 2024
# ...                                              ...
# 1031    Reviewed in the United States March 14, 2021
# 1032     Reviewed in the United States March 1, 2024
# 1033  Reviewed in the United States February 4, 2019
# 1034    Reviewed in the United States April 22, 2020
# 1035     Reviewed in the United States June 15, 2021
#
#                         profile_id  is_verified  helpful_count  \
# 0     AFPG4YAKAUOQ6GGBHNKLZ4E3JDBQ         True             12
# 1     AFHZTD2L5OXDW2RC4GDSIBRMAB6A         True             53
# 2     AHJD4656VLR6I3TCW544TITKJBUQ         True            734
# 3     AHYLFTWLZ5YY5FWN3UBI4YSR3ROQ         True            225
# 4     AG77DIMEIWDUUMGCBEAOODGVITPA         True              5
# ...                            ...          ...            ...
# 1031  AHS6VSQTRWHC6VYIDYQHUDDUMOJA         True              0
# 1032  AGCMNX3PAFXARGQTYIWGCQBSQH7Q         True              0
# 1033  AGQJUPHOYSRWOZFTRNWUUCQ6TY4Q         True              4
# 1034  AHUEHZ26MDJNOEUDDM7WDBV6W6QQ         True              1
# 1035  AHERROBAS3BWSZMIM6IGFCLCKAGQ         True              3
#
#                                      product_attributes
# 0     Color: Beats WhiteStyle: Fit ProSet: Without A...
# 1     Color: Sage GrayStyle: Fit ProSet: Without App...
# 2     Color: Sage GrayStyle: Fit ProSet: Without App...
# 3     Color: Beats BlackStyle: Fit ProSet: Without A...
# 4     Color: Tidal BlueStyle: Fit ProSet: Without Ap...
# ...                                                 ...
# 1031                                      Color: Silver
# 1032                                      Color: Silver
# 1033                                       Color: Black
# 1034                                       Color: Black
# 1035                                       Color: Black
#
# [1036 rows x 11 columns]

# %% [markdown]
# ## **1. Handling missing values**

# %% [markdown]
# **Let's first check for missing values**

# %%
missing_values = raw_data_df.isnull().sum()

# %%
missing_values
# Out:
# review_id              0
# product_id             0
# title                  0
# author                 0
# rating                 0
# content                3
# timestamp              0
# profile_id             0
# is_verified            0
# helpful_count          0
# product_attributes    61
# dtype: int64

# %% [markdown]
# **Let's check the type of data in each colum.**

# %%
raw_data_df.dtypes
# Out:
# review_id             object
# product_id            object
# title                 object
# author                object
# rating                 int64
# content               object
# timestamp             object
# profile_id            object
# is_verified             bool
# helpful_count          int64
# product_attributes    object
# dtype: object

# %% [markdown]
# We can see that the `content` and `product_attributes` columns are both of `type object`. I will remove all rows where `content` is `null` because there are only a few. For the `product_attributes` column, I will replace all missing values with the `mode.

# %%
# Remove rows where 'content' is null
raw_data_df_copy = raw_data_df.copy()
raw_data_df_copy = raw_data_df_copy.dropna(subset='content')

# %% [markdown]
# **Now let's visualize the actual result**

# %%
missing_values = raw_data_df_copy.isnull().sum()

# %%
missing_values
# Out:
# review_id              0
# product_id             0
# title                  0
# author                 0
# rating                 0
# content                0
# timestamp              0
# profile_id             0
# is_verified            0
# helpful_count          0
# product_attributes    61
# dtype: int64

# %%
# Replace missing values in 'product_attributes' with the mode
mode_product_attributes = raw_data_df_copy['product_attributes'].mode()[0]
raw_data_df_copy['product_attributes'].fillna(mode_product_attributes, inplace=True)

# %% [markdown]
# **Now let's visualize the final result again**

# %%
missing_values = raw_data_df_copy.isnull().sum()

# %%
missing_values
# Out:
# review_id             0
# product_id            0
# title                 0
# author                0
# rating                0
# content               0
# timestamp             0
# profile_id            0
# is_verified           0
# helpful_count         0
# product_attributes    0
# dtype: int64

# %% [markdown]
# **So we can see that we handle the missing values well.**

# %% [markdown]
# ## **2. Identifying and handling outliers**

# %% [markdown]
# ## **2.1 Identifying outliers**

# %% [markdown]
# **Step 1: Let's find numerical columns**

# %%
numerical_columns = raw_data_df_copy.select_dtypes(include=[np.number]).columns.tolist() # Selects all columns with numerical data types.

# %% [markdown]
# **Step 2: Let's find the first quartile (Q1), the third quartile (Q3) and calculate the IQR (Interquartile Range).**

# %%
for column in numerical_columns:
    Q1 = raw_data_df_copy[column].quantile(0.25)  # Finding the first quartile (Q1).
    Q3 = raw_data_df_copy[column].quantile(0.75)  # Finding the third quartile (Q3).
    IQR = Q3 - Q1                                 # Calculate the IQR (Interquartile Range)

# %% [markdown]
# **Step 3: Let's determine the lower and the upper bound.**

# %%
lower_bound = Q1 - 1.5 * IQR   # Determine the lower bound
upper_bound = Q3 + 1.5 * IQR   # Determine the upper bound

# %% [markdown]
# ## **2.2 Handling outliers**

# %% [markdown]
# Now that we know the `boundaries`, we can `handle the outliers` by `capping` them. This means we `replace any value outside the boundaries` with the `closest boundary value`.

# %%
raw_data_df_copy[column] = np.where(raw_data_df_copy[column] > upper_bound, upper_bound, raw_data_df_copy[column])
raw_data_df_copy[column] = np.where(raw_data_df_copy[column] < lower_bound, lower_bound, raw_data_df_copy[column])

# %% [markdown]
# ## **3. Converting categorical columns to numerical variables if necessary.**

# %% [markdown]
# *Comming soon...*

# %% [markdown]
# ## **Save the cleaned data**

# %%
cleaned_data_df = raw_data_df_copy

# %%
cleaned_data_df
# Out:
#            review_id  product_id  \
# 0     R3VJHX5IUE1GW0  B09JL41N9C
# 1     R3O2F0G4RQELXK  B09JL41N9C
# 2     R35IQTO062Y7LU  B09JL41N9C
# 3     R2LFEEQXQDETXR  B09JL41N9C
# 4     R2JXCMRVKF84KR  B09JL41N9C
# ...              ...         ...
# 1031  R1D6AFLAUH1IKB  B0756CYWWD
# 1032  R139MEJ6IWDKKW  B0756CYWWD
# 1033   REEXHGPGJMEMI  B0756CYWWD
# 1034   RKAB2RDVHYYCE  B0756CYWWD
# 1035   R47X1PKQCOKLY  B0756CYWWD
#
#                                                   title            author  \
# 0     5.0 out of 5 stars Good sound, seamless iPhone...     Bobby K - NYC
# 1     5.0 out of 5 stars Movement focused TW earbuds...               Ant
# 2     5.0 out of 5 stars Best wireless noise cancell...  theInternational
# 3     4.0 out of 5 stars Good Apple Ecosystem Option...          C. Godby
# 4     5.0 out of 5 stars Elevating the Listening Exp...           Kailash
# ...                                                 ...               ...
# 1031            4.0 out of 5 stars They’re cool I guess     Yardley Rosas
# 1032                    5.0 out of 5 stars Great Seller            Joseph
# 1033  2.0 out of 5 stars Bose QuietComfort 35 Series...      VirtualWatts
# 1034    5.0 out of 5 stars Excellent noise cancelation.    Timothy Parker
# 1035  5.0 out of 5 stars What kind of idiot would pa...       Inna Tkatch
#
#       rating                                            content  \
# 0          5  I like how secure these earphones are, comfort...
# 1          5  My pair of Beats Powerbeats Pros were starting...
# 2          5  I am a long-time user of the Bose QuietComfort...
# 3          4  Before buying the Beats Fit Pro, I've owned th...
# 4          5  I recently had the pleasure of trying out the ...
# ...      ...                                                ...
# 1031       4  For the price I was low key expecting more so ...
# 1032       5  This was exactly what I was looking for and am...
# 1033       2  I was looking for a pair of headphones to help...
# 1034       5  I bought these specifically for the noise canc...
# 1035       5  Back when I used to spend my days fumbling wit...
#
#                                            timestamp  \
# 0         Reviewed in the United States June 6, 2024
# 1        Reviewed in the United States March 8, 2024
# 2        Reviewed in the United States July 13, 2022
# 3     Reviewed in the United States February 8, 2023
# 4       Reviewed in the United States March 21, 2024
# ...                                              ...
# 1031    Reviewed in the United States March 14, 2021
# 1032     Reviewed in the United States March 1, 2024
# 1033  Reviewed in the United States February 4, 2019
# 1034    Reviewed in the United States April 22, 2020
# 1035     Reviewed in the United States June 15, 2021
#
#                         profile_id  is_verified  helpful_count  \
# 0     AFPG4YAKAUOQ6GGBHNKLZ4E3JDBQ         True            5.0
# 1     AFHZTD2L5OXDW2RC4GDSIBRMAB6A         True            5.0
# 2     AHJD4656VLR6I3TCW544TITKJBUQ         True            5.0
# 3     AHYLFTWLZ5YY5FWN3UBI4YSR3ROQ         True            5.0
# 4     AG77DIMEIWDUUMGCBEAOODGVITPA         True            5.0
# ...                            ...          ...            ...
# 1031  AHS6VSQTRWHC6VYIDYQHUDDUMOJA         True            0.0
# 1032  AGCMNX3PAFXARGQTYIWGCQBSQH7Q         True            0.0
# 1033  AGQJUPHOYSRWOZFTRNWUUCQ6TY4Q         True            4.0
# 1034  AHUEHZ26MDJNOEUDDM7WDBV6W6QQ         True            1.0
# 1035  AHERROBAS3BWSZMIM6IGFCLCKAGQ         True            3.0
#
#                                      product_attributes
# 0     Color: Beats WhiteStyle: Fit ProSet: Without A...
# 1     Color: Sage GrayStyle: Fit ProSet: Without App...
# 2     Color: Sage GrayStyle: Fit ProSet: Without App...
# 3     Color: Beats BlackStyle: Fit ProSet: Without A...
# 4     Color: Tidal BlueStyle: Fit ProSet: Without Ap...
# ...                                                 ...
# 1031                                      Color: Silver
# 1032                                      Color: Silver
# 1033                                       Color: Black
# 1034                                       Color: Black
# 1035                                       Color: Black
#
# [1033 rows x 11 columns]

# %%
cleaned_data_df.to_csv('cleaned_data_df.csv', index=False)
